# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/hp/Documents/covid_19_data.csv')

# %%
df.head(10)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6      01/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7      01/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8      01/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9      01/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10      01/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0          1       0          0
# 1         14       0          0
# 2          6       0          0
# 3          1       0          0
# 4          0       0          0
# 5         26       0          0
# 6          2       0          0
# 7          1       0          0
# 8          4       0          0
# 9          1       0          0

# %%
df.drop(['SNo','Last Update'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   ObservationDate Province/State  Country/Region  Confirmed  Deaths  Recovered
# 0      01/22/2020          Anhui  Mainland China          1       0          0
# 1      01/22/2020        Beijing  Mainland China         14       0          0
# 2      01/22/2020      Chongqing  Mainland China          6       0          0
# 3      01/22/2020         Fujian  Mainland China          1       0          0
# 4      01/22/2020          Gansu  Mainland China          0       0          0

# %%
df.rename(columns={'ObservationDate':'Date','Province/State':'Province','Country/Region':'Country'},inplace=True)

# %%
df.head()
# Out:
#          Date   Province         Country  Confirmed  Deaths  Recovered
# 0  01/22/2020      Anhui  Mainland China          1       0          0
# 1  01/22/2020    Beijing  Mainland China         14       0          0
# 2  01/22/2020  Chongqing  Mainland China          6       0          0
# 3  01/22/2020     Fujian  Mainland China          1       0          0
# 4  01/22/2020      Gansu  Mainland China          0       0          0

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
print(df['Date'].head(20))
# Out:
# 0    2020-01-22
# 1    2020-01-22
# 2    2020-01-22
# 3    2020-01-22
# 4    2020-01-22
# 5    2020-01-22
# 6    2020-01-22
# 7    2020-01-22
# 8    2020-01-22
# 9    2020-01-22
# 10   2020-01-22
# 11   2020-01-22
# 12   2020-01-22
# 13   2020-01-22
# 14   2020-01-22
# 15   2020-01-22
# 16   2020-01-22
# 17   2020-01-22
# 18   2020-01-22
# 19   2020-01-22
# Name: Date, dtype: datetime64[ns]

# %%
df.head()
# Out:
#         Date   Province         Country  Confirmed  Deaths  Recovered
# 0 2020-01-22      Anhui  Mainland China          1       0          0
# 1 2020-01-22    Beijing  Mainland China         14       0          0
# 2 2020-01-22  Chongqing  Mainland China          6       0          0
# 3 2020-01-22     Fujian  Mainland China          1       0          0
# 4 2020-01-22      Gansu  Mainland China          0       0          0

# %%
df.describe()
# Out:
#                                 Date     Confirmed       Deaths     Recovered
# count                           1970   4247.000000  4247.000000   4247.000000
# mean   2020-02-15 06:31:03.959390720    586.884624    17.530257    187.914528
# min              2020-01-22 00:00:00      0.000000     0.000000      0.000000
# 25%              2020-02-03 06:00:00      1.000000     0.000000      0.000000
# 50%              2020-02-19 00:00:00      9.000000     0.000000      1.000000
# 75%              2020-02-25 00:00:00     99.500000     1.000000     16.000000
# max              2020-02-29 00:00:00  67707.000000  2986.000000  45235.000000
# std                              NaN   5033.596411   190.278672   1976.388824

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4247 entries, 0 to 4246
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1970 non-null   datetime64[ns]
#  1   Province   2746 non-null   object
#  2   Country    4247 non-null   object
#  3   Confirmed  4247 non-null   int64
#  4   Deaths     4247 non-null   int64
#  5   Recovered  4247 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 199.2+ KB

# %%
df=df.fillna('NA')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4247 entries, 0 to 4246
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4247 non-null   object
#  1   Province   4247 non-null   object
#  2   Country    4247 non-null   object
#  3   Confirmed  4247 non-null   int64
#  4   Deaths     4247 non-null   int64
#  5   Recovered  4247 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 199.2+ KB

# %%
df
# Out:
#                      Date                              Province  \
# 0     2020-01-22 00:00:00                                 Anhui
# 1     2020-01-22 00:00:00                               Beijing
# 2     2020-01-22 00:00:00                             Chongqing
# 3     2020-01-22 00:00:00                                Fujian
# 4     2020-01-22 00:00:00                                 Gansu
# ...                   ...                                   ...
# 4242                   NA                    Northern Territory
# 4243                   NA  Lackland, TX (From Diamond Princess)
# 4244                   NA                 Montgomery County, TX
# 4245                   NA     Omaha, NE (From Diamond Princess)
# 4246                   NA    Travis, CA (From Diamond Princess)
#
#              Country  Confirmed  Deaths  Recovered
# 0     Mainland China          1       0          0
# 1     Mainland China         14       0          0
# 2     Mainland China          6       0          0
# 3     Mainland China          1       0          0
# 4     Mainland China          0       0          0
# ...              ...        ...     ...        ...
# 4242       Australia          0       0          0
# 4243              US          0       0          0
# 4244              US          0       0          0
# 4245              US          0       0          0
# 4246              US          0       0          0
#
# [4247 rows x 6 columns]

# %%
df2=df.groupby('Country')[['Confirmed','Deaths','Recovered']].sum().reset_index()

# %%
df2
# Out:
#                   Country  Confirmed  Deaths  Recovered
# 0              Azerbaijan          1       0          0
# 1             Afghanistan         17       0          0
# 2                 Algeria         91       0          0
# 3                 Andorra          7       0          0
# 4               Argentina         25       1          0
# ..                    ...        ...     ...        ...
# 106                    US       2660      90        150
# 107               Ukraine          6       0          0
# 108  United Arab Emirates        524       0        108
# 109          Vatican City          3       0          0
# 110               Vietnam        560       0        342
#
# [111 rows x 4 columns]

# %%
df2 = df.groupby(['Country','Date'])[['Confirmed', 'Deaths', 'Recovered']].sum().reset_index()

# %%
df2
# Out:
#          Country                 Date  Confirmed  Deaths  Recovered
# 0     Azerbaijan  2020-02-28 00:00:00          1       0          0
# 1    Afghanistan  2020-02-24 00:00:00          1       0          0
# 2    Afghanistan  2020-02-25 00:00:00          1       0          0
# 3    Afghanistan  2020-02-26 00:00:00          1       0          0
# 4    Afghanistan  2020-02-27 00:00:00          1       0          0
# ..           ...                  ...        ...     ...        ...
# 918      Vietnam  2020-02-26 00:00:00         16       0         16
# 919      Vietnam  2020-02-27 00:00:00         16       0         16
# 920      Vietnam  2020-02-28 00:00:00         16       0         16
# 921      Vietnam  2020-02-29 00:00:00         16       0         16
# 922      Vietnam                   NA        270       0        150
#
# [923 rows x 5 columns]

# %%
df3=df2[df2['Confirmed']>100]

# %%
df3
# Out:
#                   Country Date  Confirmed  Deaths  Recovered
# 42              Australia   NA        568      15        152
# 48                Austria   NA        361       0          0
# 56                Bahrain   NA        482       0         12
# 78                Belgium   NA        583       0          8
# 135                Canada   NA        386       0         53
# ..                    ...  ...        ...     ...        ...
# 823              Thailand   NA        685       8        330
# 844                    UK   NA       1015       8         85
# 872                    US   NA       2041      89         74
# 894  United Arab Emirates   NA        316       0         45
# 922               Vietnam   NA        270       0        150
#
# [114 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,10,1000)
y=np.sin(x)
plt.plot(x,y)

# %%
plt.scatter(x[::10],y[::10],color='red')

# %%
plt.plot(x,y,color='b')
plt.plot(x,np.cos(x),color='g')
